# %% [markdown]
# # PD-SFANC Real-World Linear Demo
#
# This notebook runs the inference-only PD-SFANC real-world linear trajectory demo and displays the generated result figure.

# %%
from pathlib import Path
import os
import sys

repo_root = Path.cwd().resolve()
if repo_root.name == "notebooks":
    repo_root = repo_root.parent
os.chdir(repo_root)
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

# %%
from scripts.run_realworld_linear import run_demo

result = run_demo(root=repo_root, output_dir=repo_root / "outputs")
result["summary"]
# Out:
# {'segments_evaluated': 36,
#  'warmup_frames': 4,
#  'top1_accuracy': 1.0,
#  'angular_mae_deg': 2.0,
#  'mean_noise_reduction_db_all': 13.562944626422677,
#  'mean_noise_reduction_db_after_warmup': 15.069938463845725,
#  'min_noise_reduction_db_after_warmup': 12.834843962847327}

# %%
from IPython.display import Image, display

display(Image(filename=str(result["figure_path"])))

# %%
import pandas as pd

pd.read_csv(result["per_frame_path"]).head(12)
# Out:
#     frame  time_s  true_azimuth_deg  selected_filter_azimuth_deg  \
# 0       0     0.0               2.0                         40.0
# 1       1     0.5              12.0                         40.0
# 2       2     1.0              22.0                         40.0
# 3       3     1.5              32.0                         40.0
# 4       4     2.0              42.0                         40.0
# 5       5     2.5              52.0                         50.0
# 6       6     3.0              62.0                         60.0
# 7       7     3.5              72.0                         70.0
# 8       8     4.0              82.0                         80.0
# 9       9     4.5              92.0                         90.0
# 10     10     5.0             102.0                        100.0
# 11     11     5.5             112.0                        110.0
#
#     noise_reduction_db
# 0         4.492984e-07
# 1        -1.583331e-07
# 2        -2.129090e-07
# 3         2.804047e-07
# 4         1.349138e+01
# 5         1.515270e+01
# 6         1.565330e+01
# 7         1.534770e+01
# 8         1.471033e+01
# 9         1.373539e+01
# 10        1.385923e+01
# 11        1.459208e+01
